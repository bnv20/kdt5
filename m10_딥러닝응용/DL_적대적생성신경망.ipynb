# %% [markdown]
# # 적대적 생성 신경망(Generative Adversarial Networks, GAN)
#
# - 2014년, Ian Goodfellow 소개
#
# - VAE와는 다른 방법으로 이미지 잠재 공간을 학습
#
# - 직관적으로 이해하는 방법
#
#   - 가짜 피카소 그림을 그리는 위조범과 이를 판별하는 판매상의 관계
#
#   - 위조품과 진짜 그림을 섞어서 판매상에게 보여주며
#     그림이 진짜인지 가짜인지 판매상은 판별하고 이를 위조범에게 피드백
#
#   - 처음에는 형편없는 그림을 그리다가 점점 피카소의 스타일을 모방하게 되고
#     판매상은 위조품을 구분하는데 점점 더 전문가가 되어감
#
# - GAN의 네트워크
#
#   - 생성자 네트워크(generator network)
#
#     - 랜덤 벡터(잠재 공간의 무작위한 포인트)를 입력으로 받아 이를 합성된 이미지로 디코딩
#
#   - 판별자 네트워크(discriminator netowrk)
#
#     - 이미지(실제 또는 가짜 이미지)를 입력으로 받아 훈련 세트에서 온 이미지인지 생성자가 만든 이미지인지 판별
#
# - GAN은 최적화의 최솟값이 고정되어 있지 않음
#
#   - 보통의 경사하강법은 **고정된 손실공간**에서 언덕을 내려오는 훈련 방법이지만
#     GAN은 매 단계가 조금씩 전체 공간을 바꾸기 때문에 최적화 과정이 최솟값을 찾는 것이 어려움
#
#   - 두 힘간의 평형점을 찾는 시스템
#
#   - 따라서, 학습과정이 매우 어려움
#     즉, 적절한 파라미터를 찾고 조정해야함
#
#   <img src="https://paperswithcode.com/media/methods/gan.jpeg">
#
#   <sub>[이미지 출처] https://paperswithcode.com/method/gan</sub>

# %% [markdown]
# ## GAN의 구현 (DCGAN)
#
# - CIFAR10 데이터셋 사용
#
# - generator 네트워크는 (latent_dim,) 크기의 벡터를 (32, 32, 3) 크기의 이미지로 매핑
#
# - discriminator 네트워크는 (32, 32, 3) 크기의 이미지가 진짜일 확률을 추정하여 이진값으로 매핑
#
# - 생성자와 판별자를 연결하는 gan 네트워크를 만듬
#
#   - gan(x) = discriminator(generator(x))
#
# - 진짜/가짜 레이블과 함께 진짜 이미지와 가짜 이미지 샘플을 사용하여 판별자를 훈련 (일반적인 이미지 분류 모델 훈련과 동일)
#
# - 생성자를 훈련하려면 gan 모델의 손실에 대한 생성자 가중치의 그래디언트를 사용
#
#   - 매 단계마다 생성자에 의해 디코딩된 이미지를 판별자가 "진짜"로 분류하도록 한다는 방향으로 생성자의 가중치를 이동
#
#   - 판별자를 속이도록 생성자를 훈련한다는 말

# %% [markdown]
# ## 학습 방법
#
# - 마지막 활성화 함수로 sigmoid 대신 tanh함수 사용
#
# - 균등분포가 아니고 정규 분포(가우시안 분포)를 사용하여 잠재 공간에서 포인트를 샘플링
#
# - 무작위성을 주입
#
#   - 판별자에 드롭아웃을 사용
#
#   - 판별자를 위해 레이블에 랜덤 노이즈를 추가
#
# - 희소한 그래디언트는 GAN 훈련에 방해가 될 수 있음
#
#   - 최대 풀링 대신 스트라이드 합성곱을 사용하여 다운샘플링
#
#   - ReLU 대신 LeakyReLU 사용
#
# - 생성자에서 픽셀 공간을 균일하게 다루지 못하여 생성된 이미지에서 체스판 모양이 종종 나타남.
#   이를 위해 생성자와 판별자에서 스트라이드 Conv2DTranpose나 Conv2D를 사용할 때 스트라이드 크기로 나누어 질 수 있는 커널 크기 사용
#
#   - 커널 크기가 스트라이드의 배수가 아니면 픽셀이 공평하게 합성곱 되지 않음
#     커널 크기를 스트라이드로 나누었을 때 나머지 크기에 해당하는 픽셀이 더 많이 업샘플링에 참여하게 됨

# %% [markdown]
# LeakyReLU : https://gooopy.tistory.com/56

# %%
import tensorflow as tf
from tensorflow.keras.layers import Input, Dense, LeakyReLU, Reshape, Conv2D, Conv2DTranspose, Flatten, Dropout
from tensorflow.keras.models import Model
import numpy as np

latent_dim = 32
height = 32
width = 32
channels = 3

generator_input = Input(shape=(latent_dim,))

x = Dense(128 * 16 * 16)(generator_input)
x = LeakyReLU()(x)
x = Reshape((16,16,128))(x)

x = Conv2DTranspose(256,4,strides=2,padding='same')(x)
x = LeakyReLU()(x)

x = Conv2D(256,5,padding='same')(x)
x = LeakyReLU()(x)
x = Conv2D(256,5,padding='same')(x)
x = LeakyReLU()(x)

x = Conv2D(channels, 7, activation='tanh', padding='same')(x)
generator = Model(generator_input,x)
generator.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 32)]              0
#
#  dense_1 (Dense)             (None, 32768)             1081344
#
#  leaky_re_lu_2 (LeakyReLU)   (None, 32768)             0
#
#  reshape_1 (Reshape)         (None, 16, 16, 128)       0
#
#  conv2d_transpose_1 (Conv2DT  (None, 32, 32, 256)      524544
#  ranspose)
#
#  leaky_re_lu_3 (LeakyReLU)   (None, 32, 32, 256)       0
#
#  conv2d_1 (Conv2D)           (None, 32, 32, 256)       1638656
#
#  leaky_re_lu_4 (LeakyReLU)   (None, 32, 32, 256)       0
#
#  conv2d_2 (Conv2D)           (None, 32, 32, 256)       1638656
#
#  leaky_re_lu_5 (LeakyReLU)   (None, 32, 32, 256)       0
#
#  conv2d_3 (Conv2D)           (None, 32, 32, 3)         37635
#
# =================================================================
# Total params: 4,920,835
# Trainable params: 4,920,835
# Non-trainable params: 0
# _________________________________________________________________

# %%
from tensorflow.keras.optimizers import RMSprop
discriminator_input = Input(shape=(height,width,channels))
x = Conv2D(128,3)(discriminator_input)
x = LeakyReLU()(x)
x = Conv2D(128,4,strides=2)(x)
x = LeakyReLU()(x)
x = Conv2D(128,4,strides=2)(x)
x = LeakyReLU()(x)
x = Conv2D(128,4,strides=2)(x)
x = LeakyReLU()(x)
x = Flatten()(x)

x = Dropout(0.4)(x)

x = Dense(1, activation='sigmoid')(x)

discriminator = Model(discriminator_input, x)
discriminator.summary()
# Out:
# Model: "model_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_3 (InputLayer)        [(None, 32, 32, 3)]       0
#
#  conv2d_4 (Conv2D)           (None, 30, 30, 128)       3584
#
#  leaky_re_lu_6 (LeakyReLU)   (None, 30, 30, 128)       0
#
#  conv2d_5 (Conv2D)           (None, 14, 14, 128)       262272
#
#  leaky_re_lu_7 (LeakyReLU)   (None, 14, 14, 128)       0
#
#  conv2d_6 (Conv2D)           (None, 6, 6, 128)         262272
#
#  leaky_re_lu_8 (LeakyReLU)   (None, 6, 6, 128)         0
#
#  conv2d_7 (Conv2D)           (None, 2, 2, 128)         262272
#
#  leaky_re_lu_9 (LeakyReLU)   (None, 2, 2, 128)         0
#
#  flatten (Flatten)           (None, 512)               0
#
#  dropout (Dropout)           (None, 512)               0
#
#  dense_2 (Dense)             (None, 1)                 513
#
# =================================================================
# Total params: 790,913
# Trainable params: 790,913
# Non-trainable params: 0
# _________________________________________________________________

# %%
discriminator_optimizer = RMSprop(learning_rate=0.0008, clipvalue=1.0, decay=1e-8)
discriminator.compile(optimizer=discriminator_optimizer, loss='binary_crossentropy')

# %%
# 판별자의 가중치가 훈련되지 않도록 설정
discriminator.trainable = False

gan_input = Input(shape=(latent_dim,))
gan_output = discriminator(generator(gan_input))
gan = Model(gan_input, gan_output)

gan_optimizer = RMSprop(learning_rate=0.0004, clipvalue=1.0, decay=1e-8)
gan.compile(optimizer=gan_optimizer, loss='binary_crossentropy')

# %%
import os 
from tensorflow.keras.datasets import cifar10
from tensorflow.keras.preprocessing import image

(x_train, y_train), (_,_) = cifar10.load_data()

# 개구리 이미지를 선택(클래스 6)
x_train = x_train[y_train.flatten() == 6] 

# 데이터 정규화
x_train = x_train.reshape((x_train.shape[0],) + (height,width,channels)).astype('float32') / 255. 

iterations = 10000
batch_size = 20
save_dir = './gan_images/'
if not os.path.exists(save_dir):
  os.mkdir(save_dir)
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170500096/170498071 [==============================] - 6s 0us/step
# 170508288/170498071 [==============================] - 6s 0us/step

# %%
labels = np.concatenate([np.ones((batch_size,1)), np.zeros((batch_size,1))])
labels += 0.05 * np.random.random(labels.shape)

# %%
# 잠재 공간에서 무작위로 포인트를 샘플링
start = 0
for step in range(iterations):
  random_latent_vectors = np.random.normal(size=(batch_size,latent_dim))
  # 랜덤 노이즐로 사용하여 generator 이미지를 생성(가짜 이미지를 디코딩)
  generated_images = generator.predict(random_latent_vectors)

  # 생성된 이미지와 진짜 이미지를 섞는다.
  stop = start + batch_size
  real_images = x_train[start:stop]
  combined_images = np.concatenate([generated_images, real_images])
  # 진짜와 가짜 이미지를 구분하여 레이블을 합침
  labels = np.concatenate([np.ones((batch_size,1)), np.zeros((batch_size,1))])
  # 레이블에 램덤 노이즈를 추가
  labels += 0.05 * np.random.random(labels.shape)

  # 진짜와 가짜가 섞인 이미지와 이에 대응하는 타깃을 사용하여 discriminator를 훈련
  d_loss = discriminator.train_on_batch(combined_images, labels)

  # 잠재 공간에서 무작위로 포인트를 샘플링
  random_latent_vectors = np.random.normal(size=(batch_size, latent_dim))

  # 모든 타깃은 진짜로 설정, 판별자가 생성된 이미지를 모두 진짜 이미지라고 예측하도록 생성자의 가중치를 업데이트
  # gan안에서 판별자는 동결되기 때문에 생성자만 업데이트, 결국 생성자는 판별자를 속이도록 훈련
  misleading_targets = np.zeros((batch_size,1))
  a_loss = gan.train_on_batch(random_latent_vectors, misleading_targets)

  start += batch_size
  if start > len(x_train) - batch_size:
    start = 0

  if step % 100 == 0:
    gan.save_weights('gan.h5')

    print(f'스탭 {step}에서 판별자 손실: {d_loss} ')
    print(f'스탭 {step}에서 적대자 손실: {a_loss} ')

    # 생성된 이미지 하나를 저장
    img = image.array_to_img(generated_images[0] * 255.,scale=False)
    img.save(os.path.join(save_dir,'real_frog'+str(step)+'.png'))
# Out:
# 스탭 0에서 판별자 손실: 0.687523365020752
# 스탭 0에서 적대자 손실: 0.6584182977676392
# 스탭 100에서 판별자 손실: 0.6684382557868958
# 스탭 100에서 적대자 손실: 0.7660964131355286
# 스탭 200에서 판별자 손실: 0.6954867243766785
# 스탭 200에서 적대자 손실: 0.754501461982727
# 스탭 300에서 판별자 손실: 0.6867122054100037
# 스탭 300에서 적대자 손실: 0.7420699596405029
# 스탭 400에서 판별자 손실: 0.6952360272407532
# 스탭 400에서 적대자 손실: 0.7304589152336121
# 스탭 500에서 판별자 손실: 0.6976873874664307
# 스탭 500에서 적대자 손실: 0.7599543333053589
# 스탭 600에서 판별자 손실: 0.7013198733329773
# 스탭 600에서 적대자 손실: 0.7361805438995361
# 스탭 700에서 판별자 손실: 0.6974135637283325
# 스탭 700에서 적대자 손실: 0.751278281211853
# 스탭 800에서 판별자 손실: 0.7366693615913391
# 스탭 800에서 적대자 손실: 0.7641832828521729
# 스탭 900에서 판별자 손실: 0.7014257311820984
# 스탭 900에서 적대자 손실: 0.7328054904937744
# 스탭 1000에서 판별자 손실: 0.6984199285507202
# 스탭 1000에서 적대자 손실: 0.6870259642601013
# 스탭 1100에서 판별자 손실: 0.6929963827133179
# 스탭 1100에서 적대자 손실: 0.7322467565536499
# 스탭 1200에서 판별자 손실: 0.664530873298645
# 스탭 1200에서 적대자 손실: 0.7906414270401001
# 스탭 1300에서 판별자 손실: 0.6879393458366394
# 스탭 1300에서 적대자 손실: 0.7411342859268188
# 스탭 1400에서 판별자 손실: 0.6804589033126831
# 스탭 1400에서 적대자 손실: 0.7528108954429626
# 스탭 1500에서 판별자 손실: 0.705416202545166
# 스탭 1500에서 적대자 손실: 0.7445275187492371
# 스탭 1600에서 판별자 손실: 0.7020227313041687
# 스탭 1600에서 적대자 손실: 0.7391432523727417
# 스탭 1700에서 판별자 손실: 0.7088189125061035
# 스탭 1700에서 적대자 손실: 0.7098141312599182
# 스탭 1800에서 판별자 손실: 0.6967399716377258
# 스탭 1800에서 적대자 손실: 0.7906734347343445
# 스탭 1900에서 판별자 손실: 0.6853703856468201
# 스탭 1900에서 적대자 손실: 0.7363976240158081
# 스탭 2000에서 판별자 손실: 0.7003957629203796
# 스탭 2000에서 적대자 손실: 0.7300159335136414
# 스탭 2100에서 판별자 손실: 0.6956359148025513
# 스탭 2100에서 적대자 손실: 0.7635537385940552
# 스탭 2200에서 판별자 손실: 0.7147294282913208
# 스탭 2200에서 적대자 손실: 0.7635765671730042
# 스탭 2300에서 판별자 손실: 0.7046106457710266
# 스탭 2300에서 적대자 손실: 0.7264372706413269
# 스탭 2400에서 판별자 손실: 0.7049129605293274
# 스탭 2400에서 적대자 손실: 0.7465571761131287
# 스탭 2500에서 판별자 손실: 0.6986424326896667
# 스탭 2500에서 적대자 손실: 0.7378982305526733
# 스탭 2600에서 판별자 손실: 0.6809727549552917
# 스탭 2600에서 적대자 손실: 0.730765700340271
# 스탭 2700에서 판별자 손실: 0.7009686827659607
# 스탭 2700에서 적대자 손실: 0.7432833313941956
# 스탭 2800에서 판별자 손실: 0.6968479752540588
# 스탭 2800에서 적대자 손실: 0.7166631817817688
# 스탭 2900에서 판별자 손실: 0.6867741346359253
# 스탭 2900에서 적대자 손실: 0.7722553014755249
# 스탭 3000에서 판별자 손실: 0.7008697390556335
# 스탭 3000에서 적대자 손실: 0.8190585374832153
# 스탭 3100에서 판별자 손실: 0.6856865882873535
# 스탭 3100에서 적대자 손실: 0.7488894462585449
# 스탭 3200에서 판별자 손실: 0.685649573802948
# 스탭 3200에서 적대자 손실: 0.7716900110244751
# 스탭 3300에서 판별자 손실: 0.7103374600410461
# 스탭 3300에서 적대자 손실: 1.2367985248565674
# 스탭 3400에서 판별자 손실: 0.6954673528671265
# 스탭 3400에서 적대자 손실: 0.7333055138587952
# 스탭 3500에서 판별자 손실: 0.6891770362854004
# 스탭 3500에서 적대자 손실: 0.673884928226471
# 스탭 3600에서 판별자 손실: 0.6938979625701904
# 스탭 3600에서 적대자 손실: 0.7499040365219116
# 스탭 3700에서 판별자 손실: 0.6981600522994995
# 스탭 3700에서 적대자 손실: 0.7330986857414246
# 스탭 3800에서 판별자 손실: 0.6827812790870667
# 스탭 3800에서 적대자 손실: 1.0992395877838135
# 스탭 3900에서 판별자 손실: 0.6815892457962036
# 스탭 3900에서 적대자 손실: 0.7432612180709839
# 스탭 4000에서 판별자 손실: 0.6915560960769653
# 스탭 4000에서 적대자 손실: 0.8340350389480591
# 스탭 4100에서 판별자 손실: 0.7034655809402466
# 스탭 4100에서 적대자 손실: 0.754233717918396
# 스탭 4200에서 판별자 손실: 0.6914284229278564
# 스탭 4200에서 적대자 손실: 0.7247617244720459
# 스탭 4300에서 판별자 손실: 0.6915294528007507
# 스탭 4300에서 적대자 손실: 0.7503782510757446
# 스탭 4400에서 판별자 손실: 0.6983064413070679
# 스탭 4400에서 적대자 손실: 0.7368075847625732
# 스탭 4500에서 판별자 손실: 0.8747828602790833
# 스탭 4500에서 적대자 손실: 0.7300496697425842
# 스탭 4600에서 판별자 손실: 0.6862765550613403
# 스탭 4600에서 적대자 손실: 0.7421736717224121
# 스탭 4700에서 판별자 손실: 0.6891844868659973
# 스탭 4700에서 적대자 손실: 0.7144830822944641
# 스탭 4800에서 판별자 손실: 0.6899985074996948
# 스탭 4800에서 적대자 손실: 0.7639693021774292
# 스탭 4900에서 판별자 손실: 0.7007037997245789
# 스탭 4900에서 적대자 손실: 0.7704371213912964
# 스탭 5000에서 판별자 손실: 0.6983291506767273
# 스탭 5000에서 적대자 손실: 0.7398506999015808
# 스탭 5100에서 판별자 손실: 0.6864652633666992
# 스탭 5100에서 적대자 손실: 0.8315760493278503
# 스탭 5200에서 판별자 손실: 0.6836601495742798
# 스탭 5200에서 적대자 손실: 0.7566943764686584
# 스탭 5300에서 판별자 손실: 0.712652325630188
# 스탭 5300에서 적대자 손실: 0.7770400643348694
# 스탭 5400에서 판별자 손실: 0.6888214349746704
# 스탭 5400에서 적대자 손실: 0.7573683857917786
# 스탭 5500에서 판별자 손실: 0.6930237412452698
# 스탭 5500에서 적대자 손실: 0.8759776949882507
# 스탭 5600에서 판별자 손실: 0.6843453049659729
# 스탭 5600에서 적대자 손실: 0.7716220617294312
# 스탭 5700에서 판별자 손실: 0.6935077905654907
# 스탭 5700에서 적대자 손실: 0.7692693471908569
# 스탭 5800에서 판별자 손실: 0.6860857009887695
# 스탭 5800에서 적대자 손실: 0.7324866056442261
# 스탭 5900에서 판별자 손실: 0.7363930940628052
# 스탭 5900에서 적대자 손실: 0.7187117338180542
# 스탭 6000에서 판별자 손실: 0.724897027015686
# 스탭 6000에서 적대자 손실: 0.7437795400619507
# 스탭 6100에서 판별자 손실: 0.6885113716125488
# 스탭 6100에서 적대자 손실: 0.7511381506919861
# 스탭 6200에서 판별자 손실: 0.6902316212654114
# 스탭 6200에서 적대자 손실: 2.0740160942077637
# 스탭 6300에서 판별자 손실: 0.6893646121025085
# 스탭 6300에서 적대자 손실: 0.7151280641555786
# 스탭 6400에서 판별자 손실: 0.8015920519828796
# 스탭 6400에서 적대자 손실: 0.7235217690467834
# 스탭 6500에서 판별자 손실: 0.6977626085281372
# 스탭 6500에서 적대자 손실: 0.702869713306427
# 스탭 6600에서 판별자 손실: 0.643425464630127
# 스탭 6600에서 적대자 손실: 0.5986289978027344
# 스탭 6700에서 판별자 손실: 0.6947044134140015
# 스탭 6700에서 적대자 손실: 1.0647283792495728
# 스탭 6800에서 판별자 손실: 0.6877360343933105
# 스탭 6800에서 적대자 손실: 0.7483895421028137
# 스탭 6900에서 판별자 손실: 0.6855559349060059
# 스탭 6900에서 적대자 손실: 0.7267416715621948
# 스탭 7000에서 판별자 손실: 0.6831604838371277
# 스탭 7000에서 적대자 손실: 0.7399767637252808
# 스탭 7100에서 판별자 손실: 0.6950265169143677
# 스탭 7100에서 적대자 손실: 0.7777646780014038
# 스탭 7200에서 판별자 손실: 0.6938117742538452
# 스탭 7200에서 적대자 손실: 0.7266227602958679
# 스탭 7300에서 판별자 손실: 0.6898244023323059
# 스탭 7300에서 적대자 손실: 0.6805971264839172
# 스탭 7400에서 판별자 손실: 0.6849268674850464
# 스탭 7400에서 적대자 손실: 0.7488046884536743
# 스탭 7500에서 판별자 손실: 0.6960687637329102
# 스탭 7500에서 적대자 손실: 0.7495174407958984
# 스탭 7600에서 판별자 손실: 0.7077804803848267
# 스탭 7600에서 적대자 손실: 0.7309113144874573
# 스탭 7700에서 판별자 손실: 0.7813143730163574
# 스탭 7700에서 적대자 손실: 0.758684515953064
# 스탭 7800에서 판별자 손실: 0.7026952505111694
# 스탭 7800에서 적대자 손실: 0.7169497609138489
# 스탭 7900에서 판별자 손실: 0.6895229816436768
# 스탭 7900에서 적대자 손실: 0.738419234752655
# 스탭 8000에서 판별자 손실: 0.6977916955947876
# 스탭 8000에서 적대자 손실: 0.7185988426208496
# 스탭 8100에서 판별자 손실: 0.6865827441215515
# 스탭 8100에서 적대자 손실: 0.7391883134841919
# 스탭 8200에서 판별자 손실: 0.708331286907196
# 스탭 8200에서 적대자 손실: 0.7333932518959045
# 스탭 8300에서 판별자 손실: 0.6925047039985657
# 스탭 8300에서 적대자 손실: 0.7343008518218994
# 스탭 8400에서 판별자 손실: 0.6932260990142822
# 스탭 8400에서 적대자 손실: 0.7363057732582092
# 스탭 8500에서 판별자 손실: 0.6971306800842285
# 스탭 8500에서 적대자 손실: 0.7577760815620422
# 스탭 8600에서 판별자 손실: 0.682279109954834
# 스탭 8600에서 적대자 손실: 0.7333704233169556
# 스탭 8700에서 판별자 손실: 0.686691403388977
# 스탭 8700에서 적대자 손실: 0.7263811230659485
# 스탭 8800에서 판별자 손실: 0.7004871964454651
# 스탭 8800에서 적대자 손실: 0.7262033224105835
# 스탭 8900에서 판별자 손실: 0.6720598340034485
# 스탭 8900에서 적대자 손실: 0.7641528844833374
# 스탭 9000에서 판별자 손실: 0.6928494572639465
# 스탭 9000에서 적대자 손실: 0.7211052179336548
# 스탭 9100에서 판별자 손실: 0.7005511522293091
# 스탭 9100에서 적대자 손실: 0.7244482040405273
# 스탭 9200에서 판별자 손실: 0.6947486400604248
# 스탭 9200에서 적대자 손실: 0.7264185547828674
# 스탭 9300에서 판별자 손실: 0.7005028128623962
# 스탭 9300에서 적대자 손실: 0.742141604423523
# 스탭 9400에서 판별자 손실: 0.6891533136367798
# 스탭 9400에서 적대자 손실: 0.6947828531265259
# 스탭 9500에서 판별자 손실: 0.6835314631462097
# 스탭 9500에서 적대자 손실: 0.7353898882865906
# 스탭 9600에서 판별자 손실: 0.6836676597595215
# 스탭 9600에서 적대자 손실: 0.7315293550491333
# 스탭 9700에서 판별자 손실: 0.7061426043510437
# 스탭 9700에서 적대자 손실: 0.9803299903869629
# 스탭 9800에서 판별자 손실: 0.6961842775344849
# 스탭 9800에서 적대자 손실: 0.7626386880874634
# 스탭 9900에서 판별자 손실: 0.6971115469932556
# 스탭 9900에서 적대자 손실: 0.7650707364082336

# %%
import matplotlib.pyplot as plt
random_latent_vectors = np.random.normal(size=(10,latent_dim))
generated_images = generator.predict(random_latent_vectors)
print(generated_images.shape)

plt.figure(figsize=(20,8))

for i in range(generated_images.shape[0]):
  plt.subplot(2,5,i+1)
  plt.imshow(img)
  plt.xticks([])
  plt.yticks([])

plt.show()
# Out:
# (10, 32, 32, 3)

# %% [markdown]
# [과제] mnist datasets로 DCGAN을 수행하세요.
